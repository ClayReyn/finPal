# %%
import numpy as np
import pandas as pd
from datetime import date, datetime, timedelta
from finta import TA
import psycopg2
from sqlalchemy import create_engine

from afternoonT_app import afternoonT

# %%
afternoonT = afternoonT()

# %%
afternoonT.steep( 
    in_dbTable='gd_ohlcv',
    out_dbTable='gd_wTi_ohlcv',
    stISOf='2020-08-06',
    endISOf='2021-08-06'
)
# Out:
# 1 of 5879: A >> gd_wTi_ohlcv
#
# 2 of 5879: AA >> gd_wTi_ohlcv
#
# 3 of 5879: AAC >> gd_wTi_ohlcv
#
# 4 of 5879: AACQ >> gd_wTi_ohlcv
#
# 5 of 5879: AAIC >> gd_wTi_ohlcv
#
# 6 of 5879: AAL >> gd_wTi_ohlcv
#
# 7 of 5879: AAMC >> gd_wTi_ohlcv
#
# 8 of 5879: AAME >> gd_wTi_ohlcv
#
# 9 of 5879: AAN >> gd_wTi_ohlcv
#
# 10 of 5879: AANw >> gd_wTi_ohlcv
#
# 11 of 5879: AAOI >> gd_wTi_ohlcv
#
# 12 of 5879: AAON >> gd_wTi_ohlcv
#
# 13 of 5879: AAP >> gd_wTi_ohlcv
#
# 14 of 5879: AAPL >> gd_wTi_ohlcv
#
# 15 of 5879: AAQC >> gd_wTi_ohlcv
#
# 16 of 5879: AAT >> gd_wTi_ohlcv
#
# 17 of 5879: AATC >> gd_wTi_ohlcv
#
# 18 of 5879: AAU >> gd_wTi_ohlcv
#
# 19 of 5879: AAWW >> gd_wTi_ohlcv
#
# 20 of 5879: AAXN >> gd_wTi_ohlcv
#
# 21 of 5879: AB >> gd_wTi_ohlcv
#
# 22 of 5879: ABBV >> gd_wTi_ohlcv
#
# 23 of 5879: ABC >> gd_wTi_ohlcv
#
# 24 of 5879: ABCB >> gd_wTi_ohlcv
#
# 25 of 5879: ABCL >> gd_wTi_ohlcv
#
# 26 of 5879: ABEO >> gd_wTi_ohlcv
#
# 27 of 5879: ABG >> gd_wTi_ohlcv
#
# ...
