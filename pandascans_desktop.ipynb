# %%
from datetime import date, datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import psycopg2
import seaborn as sns
from sqlalchemy import create_engine

import finPal_pandascan

pandascan = finPal_pandascan.pandascan()

datetime.strftime(datetime.today(), '%Y-%m-%d')
# Out:
# '2021-08-09'

# %%
dbTable = 'gd_wTi_2021-08-07'
scandate = '2021-08-06'
min_avgVol_30d = '140000'
orderBy = 'vwap'

# %%
scanql = ( 
    '''
    SELECT * FROM "{dbTable}"
    WHERE "date" LIKE '{scandate}'
    AND "avgVol_30d" > {min_avgVol_30d}
    ORDER BY "{orderBy}" DESC;
    '''
).format(dbTable=dbTable, scandate=scandate, min_avgVol_30d=min_avgVol_30d, orderBy=orderBy)

engine = ( 
    create_engine(
        'postgresql+psycopg2://postgres:s@unAsh*w3r@localhost/market'
    )
)
dbdf = pd.read_sql_query(sql=scanql, con=engine)

dbdf.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3620 entries, 0 to 3619
# Columns: 220 entries, ticker to close_pctf_ATRonSMA10
# dtypes: float64(215), int64(2), object(3)
# memory usage: 6.5 MB

# %% [markdown]
# ---
# ## | bop + close_24_sub_n_pctf_1wk_low

# %%
''' name : code 1'''

dbdf.loc[ 
    (
        dbdf['bop'].between(
            left=-0.0344827586206888,
            right=1.0
        )
    ) & ( 
        dbdf['close_24_sub_n_pctf_1wk_low'].between( 
            left=-3.6352244246981,
            right=-0.989618477282944
        )
    ) & ( 
        dbdf['VIp_chngpct_24'].between( 
            left=0.248481069328843,
            right=66.0881285943027
        )
    ) & ( 
        dbdf['MACD_sub_nMACD_Sig_n_diff'].between( 
            left=-0.632410293660814,
            right=-0.0208748448896303
        )
    )
]
# Out:
# Empty DataFrame
# ...

# %%
''' name: code 2 '''

dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['VIp_chngpct_48'].between( 
                left=-1.12179978077341,
                right=50.834378169798
            )
        ) & ( 
            dbdf['EFI_diff_n_24'].between( 
                left=-10122471.3945867,
                right=-15114.5246037209
            )
        )
]
# Out:
#      ticker     volume     vwap     open  close     high    low  \
# 1615   HEAR   602321.0  28.0187  28.4008  28.40  28.8999  26.91
# 2237  LGF.A   948291.0  14.2406  14.1200  14.23  14.5350  13.50
# 2307     AG  3121333.0  12.9965  12.8300  13.08  13.1950  12.71
# 2872     HL  6371885.0   6.1286   6.0000   6.20   6.2300   5.98
#
#           timestamp  transactions        date  ...  close_pctf_SMA50  \
# 1615  1628280000000        7054.0  2021-08-06  ...        -11.260538
# 2237  1628280000000       10843.0  2021-08-06  ...        -23.154188
# 2307  1628280000000       17610.0  2021-08-06  ...        -15.046179
# 2872  1628280000000       25508.0  2021-08-06  ...        -18.739679
#
#       SMA10_pctf_SMA50   SMA100 close_pctf_SMA100  SMA10_pctf_SMA100  \
# 1615         -6.301752  29.8654        -11.260538           0.407160
# 2237        -19.238994  17.3271        -23.154188         -13.690115
# 2307        -13.760181  15.8914        -15.046179         -16.445373
# ...

# %%
''' name: code 3 '''

dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['VIp_div_VIm_chngpct_24'].between( 
                left=-1.31233880869641,
                right=71.0154728635913
            )
        ) & ( 
            dbdf['WOBV_chngpct_24'].between( 
                left=-11122.4058683351,
                right=-0.785865762803328
            )
        )
]
# Out:
#      ticker     volume     vwap  open  close   high    low      timestamp  \
# 2278   GATO   875963.0  13.4494  13.5   13.5  13.70  12.84  1628280000000
# 2872     HL  6371885.0   6.1286   6.0    6.2   6.23   5.98  1628280000000
#
#       transactions        date  ...  close_pctf_SMA50  SMA10_pctf_SMA50  \
# 2278        6846.0  2021-08-06  ...        -17.551210        -16.873298
# 2872       25508.0  2021-08-06  ...        -18.739679        -14.807728
#
#        SMA100 close_pctf_SMA100  SMA10_pctf_SMA100  SMA50_pctf_SMA100  \
# 2278  14.1901        -17.551210          -4.081014          15.388898
# 2872   7.1679        -18.739679          -9.317931           6.444007
#
#       SMA10_plus_TR  close_pctf_TRonSMA10  SMA10_plus_ATR  \
# 2278         14.471             -6.709972       14.379093
# 2872          6.860             -9.620991        6.822486
#
#       close_pctf_ATRonSMA10
# 2278              -6.113688
# 2872              -9.124031
#
# [2 rows x 220 columns]

# %%
''' name : code 4 '''

dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['bullPwr_diff_n_24'].between( 
                left=-12.2702620028771,
                right=-0.255283014371189
            )
        ) & ( 
            dbdf['perf_1mo'].between( 
                left=-13.8451911347686,
                right=-1.92526521899627
            )
        )
]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ---
# ## | bop_diff_n_24 + RSI7_div_RSI14_chngpct_24

# %%
''' name : code 5 '''

dbdf.loc[ 
        (
            dbdf['bop_diff_n_24'].between(
                left= 0.847660246274722,
                right= 2.0
            )
        ) & ( 
            dbdf['RSI7_div_RSI14_chngpct_24'].between( 
                left= -73.4032707603346,
                right= -0.972687810693496
            )
        ) & ( 
            dbdf['pctK_div_pctD_chngpct_24'].between( 
                left= 262.263214486447,
                right= 273387.705557057
            )
        ) & ( 
            dbdf['VIp_div_VIm_chngpct_48'].between( 
                left= -14.7396795530375,
                right= 314.208341638019
            )
        )
]
# Out:
# Empty DataFrame
# ...

# %%
''' code: 6 '''

dbdf.loc[ 
        (
            dbdf['bop_diff_n_24'].between(
                left= 0.847660246274722,
                right= 2.0
            )
        ) & ( 
            dbdf['RSI7_div_RSI14_chngpct_24'].between( 
                left= -73.4032707603346,
                right= -0.972687810693496
            )
        ) & ( 
            dbdf['pctK_chngpct_24'].between( 
                left= 246.666666666656,
                right= 2552548.37268666
            )
        ) & ( 
            dbdf['RSI7_chngpct_24'].between( 
                left= -79.3594038192463,
                right= -7.84150793487602
            )
        )
]
# Out:
# Empty DataFrame
# ...

# %%
''' code: 7 '''
''' 366 / 398 | 0.920 (july 6 - august 6) '''

dbdf.loc[ 
        (
            dbdf['bop_diff_n_24'].between(
                left= 0.847660246274722,
                right= 2.0
            )
        ) & ( 
            dbdf['RSI7_div_RSI14_chngpct_24'].between( 
                left= -73.4032707603346,
                right= -0.972687810693496
            )
        ) & ( 
            dbdf['MOM5'].between( 
                left= -168.96,
                right= -1.13
            )
        ) & ( 
            dbdf['RSI7_chngpct_24'].between( 
                left= -79.3594038192463,
                right= -7.84150793487602
            )
        )
]
# Out:
#     ticker     volume      vwap    open   close    high     low  \
# 450   RGLD   325989.0  115.7769  115.39  116.06  116.51  114.11
# 592   LOPE   385304.0   89.9992   88.83   89.55   91.66   88.83
# 909    AEM  1270547.0   60.3854   60.30   60.53   60.89   59.70
#
#          timestamp  transactions        date  ...  close_pctf_SMA50  \
# 450  1628280000000        7816.0  2021-08-06  ...         -1.400075
# 592  1628280000000        6930.0  2021-08-06  ...         -1.277059
# 909  1628280000000       15758.0  2021-08-06  ...         -6.318002
#
#      SMA10_pctf_SMA50    SMA100 close_pctf_SMA100  SMA10_pctf_SMA100  \
# 450          0.630373  116.1990         -1.400075           1.937194
# 592          0.762443   98.1707         -1.277059          -6.896864
# 909         -3.652871   64.5004         -6.318002          -3.485870
#
#      SMA50_pctf_SMA100  SMA10_plus_TR  close_pctf_TRonSMA10  SMA10_plus_ATR  \
# ...

# %% [markdown]
# ---
# ## | RSI7_chngpct_24 + bop_sub_p_vhigh_1wk

# %%
''' code: 8 '''
''' 102 / 113 | 0.903 (july 6 - august 6) '''

dbdf.loc[ 
        (
            dbdf['RSI7_chngpct_24'].between(
                left= -94.8258405816019,
                right= -1.7799533681546
            )
        ) & ( 
            dbdf['bop_sub_p_vhigh_1wk'].between( 
                left= -0.298095691865992,
                right= 0.975308641975314
            )
        ) & ( 
            dbdf['pctD_chngpct_24'].between( 
                left= 10.1916324817648,
                right= 199.135908730818
            )
        ) & ( 
            dbdf['pctD_chngpct_48'].between( 
                left= -87.3431911850693,
                right= -7.63687242651038
            )
        )
]
# Out:
# Empty DataFrame
# ...

# %%
''' code: 9 '''
''' 250 / 283 | 0.883 (july 6 - august 6) '''

dbdf.loc[ 
        (
            dbdf['RSI7_chngpct_24'].between(
                left= -94.8258405816019,
                right= -1.7799533681546
            )
        ) & ( 
            dbdf['bop_sub_p_vhigh_1wk'].between( 
                left= -0.298095691865992,
                right= 0.975308641975314
            )
        ) & ( 
            dbdf['pctK_chngpct_24'].between( 
                left= 3.84726827854829,
                right= 1891791.89189189
            )
        ) & ( 
            dbdf['EFI_diff_n_24'].between( 
                left= -32523874.3241804,
                right= -8609.22274980179
            )
        )
]
# Out:
#      ticker      volume     vwap   open  close    high    low      timestamp  \
# 1376   COLD  10450336.0  36.7702  35.25  37.21  37.400  34.84  1628280000000
# 2237  LGF.A    948291.0  14.2406  14.12  14.23  14.535  13.50  1628280000000
#
#       transactions        date  ...  close_pctf_SMA50  SMA10_pctf_SMA50  \
# 1376       54920.0  2021-08-06  ...         -3.917660         -0.439484
# 2237       10843.0  2021-08-06  ...        -23.154188        -19.238994
#
#        SMA100 close_pctf_SMA100  SMA10_pctf_SMA100  SMA50_pctf_SMA100  \
# 1376  38.6527         -3.917660          -0.247589           0.192742
# 2237  17.3271        -23.154188         -13.690115           6.870740
#
#       SMA10_plus_TR  close_pctf_TRonSMA10  SMA10_plus_ATR  \
# 1376         42.447            -12.337739       39.593636
# 2237         16.165            -11.970306       15.676779
#
#       close_pctf_ATRonSMA10
# 1376               -6.02025
# 2237               -9.22880
#
# [2 rows x 220 columns]

# %% [markdown]
# ---

# %%
dbdf.sort_values(by='volume', ascending=False, inplace=True)
dbdf[['ticker', 'open', 'high', 'low', 'close', 'vwap', 'volume']].loc[lookup_idx].iloc[:50]

# %% [markdown]
# ---
# # | backscans

# %%
dbTable = 'gd_wTi_2021-08-07'

stDate = '2021-07-06'
endDate = '2021-08-06'

min_avgVol_30d = '140000'

orderBy = 'close_chngpct_24_tmro'

# %%
scanql = ( 
    '''
    SELECT * FROM "{dbTable}"
    WHERE "date" BETWEEN '{stDate}' AND '{endDate}'
    AND "avgVol_30d" > {min_avgVol_30d}
    ORDER BY "{orderBy}";
    '''
).format(dbTable=dbTable, stDate=stDate, endDate=endDate, min_avgVol_30d=min_avgVol_30d, orderBy=orderBy)


engine = ( 
    create_engine(
        'postgresql+psycopg2://postgres:s@unAsh*w3r@localhost/market'
    )
)
dbdf = pd.read_sql_query(sql=scanql, con=engine)

dbdf.drop(index=dbdf.loc[dbdf['close_chngpct_24_tmro'].isnull()].index, inplace=True)
dbdf.sort_values(by='close_chngpct_24_tmro', ascending=False, ignore_index=True, inplace=True)

dbdf.info(memory_usage='deep')

# %% [markdown]
# ---

# %%
''' 103 / 103 | 100% (july 6 - august 6) '''

len(
    dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['VIp_chngpct_24'].between( 
                left=0.248481069328843,
                right=66.0881285943027
            )
        ) & ( 
            dbdf['MACD_sub_nMACD_Sig_n_diff'].between( 
                left=-0.632410293660814,
                right=-0.0208748448896303
            )
        )
    ]
)

# %%
len(
    dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['VIp_chngpct_24'].between( 
                left=0.248481069328843,
                right=66.0881285943027
            )
        ) & ( 
            dbdf['MACD_sub_nMACD_Sig_n_diff'].between( 
                left=-0.632410293660814,
                right=-0.0208748448896303
            )
        ) & ( 
            dbdf['close_chngpct_24_tmro'] > 0
        )
    ]
)

# %% [markdown]
# ---

# %%
''' 128 / 131 | 0.977 (july 6 - august 6) '''
len(
    dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['VIp_chngpct_48'].between( 
                left=-1.12179978077341,
                right=50.834378169798
            )
        ) & ( 
            dbdf['EFI_diff_n_24'].between( 
                left=-10122471.3945867,
                right=-15114.5246037209
            )
        ) & ( 
            dbdf['close_chngpct_24_tmro'] > 0
        )
    ]
)

# %%
''' 215 / 221 | 0.977 (july 6 - august 6) '''
len(
    dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['VIp_div_VIm_chngpct_24'].between( 
                left=-1.31233880869641,
                right=71.0154728635913
            )
        ) & ( 
            dbdf['WOBV_chngpct_24'].between( 
                left=-11122.4058683351,
                right=-0.785865762803328
            )
        ) & ( 
            dbdf['close_chngpct_24_tmro'] > 0
        )
    ]
)

# %%
''' 332 / 349 | 0.951 (july 6 - august 6) '''
len(
    dbdf.loc[ 
        (
            dbdf['bop'].between(
                left=-0.0344827586206888,
                right=1.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( 
            dbdf['bullPwr_diff_n_24'].between( 
                left=-12.2702620028771,
                right=-0.255283014371189
            )
        ) & ( 
            dbdf['perf_1mo'].between( 
                left=-13.8451911347686,
                right=-1.92526521899627
            )
        ) & ( 
            dbdf['close_chngpct_24_tmro'] > 0
        )
    ]
)

# %% [markdown]
# ---

# %%
len( 
    dbdf.loc[ 
        (
            dbdf['bop_diff_n_24'].between(
                left=0.847660246274722,
                right=2.0
            )
        ) & ( 
            dbdf['close_24_sub_n_pctf_1wk_low'].between( 
                left=-3.6352244246981,
                right=-0.989618477282944
            )
        ) & ( dbdf['close_chngpct_24_tmro'] > 0)
    ]
)

# %%
pandascan.bop__normBP_chngpct_24__close_24_sub_n_pctf_1wk_low(df=dbdf)

# %%
pandascan.blip_array

# %%
blip_df = pandascan.return_blip_df()
blip_df

# %%
lookup_idx = blip_df.loc[
    blip_df['filters'] == 'bop_volume_vwap_close_24_sub_n_pctf_1wk_low'
]['blips_idx'][0]

# %%
pandascan.Ov0c_of( 
    df=dbdf,
    Ov0_cutoff=0,
    test_idx=lookup_idx,
    test_name='bop__close_24_sub_n_pctf_1wk_low'
)

# %%
dbdf.loc[lookup_idx]

# %% [markdown]
# ---
# ## | subset

# %%
pandascan.bop__vwap__pctK_div_pctD_chngpct_48__close_24_sub_n_pctf_1wk_low( 
    df=(
        dbdf.loc[
            dbdf['date'].between( 
                left='2021-07-01',
                right='2021-08-07'
            )
        ]
    )
)

# %%
blip_df = pandascan.return_blip_df()
blip_df

# %%
blip_df.at[1, 'blips_idx']

# %%
pandascan.Ov0c_of(
    df=(
        dbdf.loc[
            dbdf['date'].between( 
                left='2021-07-01',
                right='2021-08-07'
            )
        ]
    ),
    Ov0_cutoff=0,
    test_idx=( 
        blip_df.at[1, 'blips_idx']
    ),
    test_name='july_bop_volume_vwap_close_24_sub_n_pctf_1wk_low'
)
